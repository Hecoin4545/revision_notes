# %% [markdown]
# # Ridge Regression <br>
# --Agar kabhi linear regression mai overfitting aa rahi ho than we can use this <br>
# ![Screenshot 2025-06-24 010124.png](attachment:496f2673-aa7b-41be-a08f-b97d8b29d63a.png)

# %% [markdown]
# ## Lasso And Elasticnet Regression <br>
# ![Screenshot 2025-06-24 012522.png](attachment:bba26ea8-d8fb-47f0-a358-b4c16abc7666.png)
